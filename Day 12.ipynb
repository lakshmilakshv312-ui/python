# %%
n = 7
for i in range(n):
    for j in range(5):
        if j == 0 or j == 4 or i == n//2:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# *       *
# *       *
# *       *
# * * * * *
# *       *
# *       *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or j == n//2:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# * * * * *
#     *
#     *
#     *
#     *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or j == 0 or j == n-1 or i ==2:
            print("*", end = " ")
        else:
            print(" ", end = " ")
    print()
# Out:
# * * * * *
# *       *
# * * * * *
# *       *
# *       *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or j == 0 or j == n or i ==3:
            print("*", end = " ")
        else:
            print(" ", end = " ")
    print()
# Out:
# * * * * *
# *
# *
# * * * * *
# *

# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or j == 0 or j == n+3 or i == 2:
            print("*", end = " ")
        else:
            print(" ", end = " ")
    print()
# Out:
# * * * * *
# *
# * * * * *
# *
# *

# %%
# Student Marks Management System
def add_student():
    name = input("Enter student name: ")
    marks = []
    
    for i in range(3):
        mark = int(input(f"Enter marks for subject {i+1}: "))
        marks.append(mark)
    
    return name, marks

def calculate_total(marks):
    return sum(marks)

def calculate_average(marks):
    return sum(marks) / len(marks)

def find_grade(avg):
    if avg >= 90:
        return "A Grade"
    elif avg >= 75:
        return "B Grade"
    elif avg >= 60:
        return "C Grade"
    elif avg >= 40:
        return "D Grade"
    else:
        return "Fail"

def display_student(name, marks):
    total = calculate_total(marks)
    average = calculate_average(marks)
    grade = find_grade(average)

    print("\n----- Student Report -----")
    print("Name:", name)
    print("Marks:", marks)
    print("Total:", total)
    print("Average:", round(average, 2))
    print("Grade:", grade)
    print("--------------------------")
# Main Program
students = {}
while True:
    print("\n1. Add Student")
    print("2. Display Student")
    print("3. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        name, marks = add_student()
        students[name] = marks
        print("Student added successfully!")

    elif choice == "2":
        name = input("Enter student name to display: ")
        if name in students:
            display_student(name, students[name])
        else:
            print("Student not found!")

    elif choice == "3":
        print("Exiting program...")
        break
    else:
        print("Invalid choice! Please try again.")
# Out:
# 1. Add Student
# 2. Display Student
# 3. Exit
# Enter your choice:  1
# Enter student name:  chandamama
# Enter marks for subject 1:  90
# Enter marks for subject 2:  95
# Enter marks for subject 3:  89
# Student added successfully!
#
# 1. Add Student
# 2. Display Student
# 3. Exit
# Enter your choice:  1
# Enter student name:  likitha
# Enter marks for subject 1:  80
# Enter marks for subject 2:  85
# Enter marks for subject 3:  89
# Student added successfully!
#
# 1. Add Student
# 2. Display Student
# 3. Exit
# Enter your choice:  2
# Enter student name to display:  chandamama
# ----- Student Report -----
# Name: chandamama
# Marks: [90, 95, 89]
# Total: 274
# Average: 91.33
# Grade: A Grade
# --------------------------
#
# 1. Add Student
# 2. Display Student
# 3. Exit
# Enter your choice:  2
# Enter student name to display:  likitha
# ----- Student Report -----
# Name: likitha
# Marks: [80, 85, 89]
# Total: 254
# Average: 84.67
# Grade: B Grade
# --------------------------
#
# ...
